# %% [markdown]
# <a href="https://colab.research.google.com/github/manojbhukya/pandas-/blob/main/manoj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/electronic-card-transactions-july-2024-csv-tables.xlsx.csv')
df
# Out:
#       Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5         NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2         NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5         NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
# ...                ...      ...         ...         ...    ...      ...
# 20629       ECTQ.S4AXP  2023.06        33.0         NaN      F  Percent
# 20630       ECTQ.S4AXP  2023.09        33.2         NaN      F  Percent
# 20631       ECTQ.S4AXP  2023.12        32.7         NaN      F  Percent
# 20632       ECTQ.S4AXP  2024.03        32.1         NaN      F  Percent
# 20633       ECTQ.S4AXP  2024.06        33.3         NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
df.tail()
# Out:
#       Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 20629       ECTQ.S4AXP  2023.06        33.0         NaN      F  Percent
# 20630       ECTQ.S4AXP  2023.09        33.2         NaN      F  Percent
# 20631       ECTQ.S4AXP  2023.12        32.7         NaN      F  Percent
# 20632       ECTQ.S4AXP  2024.03        32.1         NaN      F  Percent
# 20633       ECTQ.S4AXP  2024.06        33.3         NaN      F  Percent
#
#        Magnitude                                        Subject  \
# 20629          0  Electronic Card Transactions (ANZSIC06) - ECT
# 20630          0  Electronic Card Transactions (ANZSIC06) - ECT
# 20631          0  Electronic Card Transactions (ANZSIC06) - ECT
# 20632          0  Electronic Card Transactions (ANZSIC06) - ECT
# 20633          0  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                    Group Series_title_1  \
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       ECTA.S19A1  2001.03      2462.5         NaN      F  Dollars
# 1       ECTA.S19A1  2002.03     17177.2         NaN      F  Dollars
# 2       ECTA.S19A1  2003.03     22530.5         NaN      F  Dollars
# 3       ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4       ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
#
#    Magnitude                                        Subject  \
# 0          6  Electronic Card Transactions (ANZSIC06) - ECT
# 1          6  Electronic Card Transactions (ANZSIC06) - ECT
# 2          6  Electronic Card Transactions (ANZSIC06) - ECT
# 3          6  Electronic Card Transactions (ANZSIC06) - ECT
# 4          6  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# ...

# %%
df.size
# Out:
# 288876

# %%
df.shape
# Out:
# (20634, 14)

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#              Period    Data_value  Suppressed     Magnitude  Series_title_4  \
# count  20634.000000  1.951300e+04         0.0  20634.000000             0.0
# mean    2012.541687  1.614068e+07         NaN      4.217214             NaN
# std        6.715457  8.971881e+07         NaN      2.742035             NaN
# min     2000.010000 -5.130000e+01         NaN      0.000000             NaN
# 25%     2007.030000  2.019000e+02         NaN      0.000000             NaN
# 50%     2012.120000  1.274200e+03         NaN      6.000000             NaN
# 75%     2018.100000  4.626000e+03         NaN      6.000000             NaN
# max     2024.070000  1.982349e+09         NaN      6.000000             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN
